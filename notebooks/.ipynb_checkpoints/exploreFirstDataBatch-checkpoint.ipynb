# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,8)
import SimpleITK as sitk
import sys, os
import numpy as np
from scipy import ndimage as ndi
import skimage as skim
from skimage import feature
import pandas as pd
import xarray as xr
# %matplotlib inline

# %%
temp_data_dir = '/pghbio/dbmi/batmanlab/bpollack/predictElasticity/data/MRE/406/DICOM/ST00001'
full_data_dir = '/pghbio/dbmi/batmanlab/bpollack/predictElasticity/data/MRE/'
subdir_names = ['SE00001','SE00002','SE00003','SE00004','SE00005','SE00006']

# %%
#for fn in subdir_names:
for fn in ['SE00002']:
    print( "Reading Dicom directory:", temp_data_dir )
    
    reader = sitk.ImageSeriesReader()
    dicom_names = reader.GetGDCMSeriesFileNames( temp_data_dir + '/' + fn )
    reader.SetFileNames(dicom_names)
    reader.MetaDataDictionaryArrayUpdateOn()
    reader.LoadPrivateTagsOn()
    image = reader.Execute()
    size = image.GetSize()
    dims = image.GetSpacing()
    print( "Image size:", size[0], size[1], size[2] )
    print( "Image dims:", dims[0], dims[1], dims[2] )

    print( "Writing image:", temp_data_dir + '/' + fn + '.nii' )

    sitk.WriteImage( image, temp_data_dir + '/' + fn + '.nii' )

#if ( not "SITK_NOSHOW" in os.environ ):
#    sitk.Show( image, "Dicom Series" )
# Out:
# Reading Dicom directory: /pghbio/dbmi/batmanlab/bpollack/predictElasticity/data/MRE/406/DICOM/ST00001
# Image size: 512 512 4
# Image dims: 0.8594 0.8594 11.5
# Writing image: /pghbio/dbmi/batmanlab/bpollack/predictElasticity/data/MRE/406/DICOM/ST00001/SE00002.nii

# %%
index = []
vals = []
for k in reader.GetMetaDataKeys(0):
    v = reader.GetMetaData(0,k)
    print("({0}) = = \"{1}\"".format(k,v))
    index.append(k)
    vals.append(v)
s2 = pd.Series(index=index, data=vals)
# Out:
# (0008|0005) = = "ISO_IR 100"
# (0008|0008) = = "ORIGINAL\PRIMARY\OTHER"
# (0008|0016) = = "1.2.840.10008.5.1.4.1.1.4"
# (0008|0018) = = "1.3.6.1.4.1.25403.88623636059514.16184.20181106044711.2"
# (0008|0020) = = "20181106"
# (0008|0021) = = "20181106"
# (0008|0022) = = "20181106"
# (0008|0023) = = "20181106"
# (0008|0030) = = "070444"
# (0008|0031) = = ""
# (0008|0032) = = "072102"
# (0008|0033) = = "072102"
# (0008|0050) = = ""
# (0008|0060) = = "MR"
# (0008|0070) = = "GE MEDICAL SYSTEMS"
# (0008|0080) = = ""
# (0008|0090) = = ""
# (0008|1010) = = ""
# (0008|1030) = = "Abd Abdom Contrast  "
# (0008|103e) = = ""
# (0008|1090) = = "Signa HDxt"
# (0010|0010) = = ""
# (0010|0020) = = ""
# (0010|0030) = = "19680101"
# (0010|0040) = = ""
# (0010|1010) = = ""
# (0010|1030) = = ""
# (0010|21b0) = = ""
# (0018|0015) = = ""
# (0018|0020) = = "GR"
# (0018|0021) = = "SS\SK "
# (0018|0022) = = "FAST_GEMS\SAT_GEMS\EDR_GEMS\FILTERED_GEMS\ACC_GEMS\PFP\FS "
# (0018|0023) = = "3D"
# (0018|0025) = = "N "
# (0018|0050) = = "4.6 "
# (0018|0080) = = "3.848 "
# (0018|0081) = = "1.796 "
# (0018|0082) = = "7 "
# (0018|0083) = = "0.725806"
# (0018|0084) = = "63.863445 "
# (0018|0085) = = "1H"
# (0018|0086) = = "1 "
# (0018|0087) = = "1.5 "
# (0018|0088) = = "2.3 "
# (0018|0091) = = "1 "
# (0018|0093) = = "72.5807 "
# (0018|0094) = = "100 "
# (0018|0095) = = "244.141 "
# (0018|1000) = = ""
# (0018|1020) = = "23\LX\MR Software release:HD23.0_V02_1406.a "
# (0018|1030) = = "Liver "
# (0018|1088) = = "0 "
# (0018|1090) = = "0 "
# (0018|1094) = = "0 "
# (0018|1100) = = "440 "
# (0018|1250) = = "8Ch Body FullFOV"
# (0018|1310) = = "288\0\0\160"
# (0018|1312) = = "COL "
# (0018|1314) = = "12"
# (0018|1315) = = "N "
# (0018|1316) = = "0.623342"
# (0018|5100) = = "FFS "
# (0020|000d) = = "1.3.6.1.4.1.25403.88623636059514.16184.20181106044710.2"
# (0020|000e) = = "1.3.6.1.4.1.25403.88623636059514.16184.20181106044711.1"
# (0020|0010) = = ""
# (0020|0011) = = ""
# (0020|0012) = = "1 "
# (0020|0013) = = "82"
# (0020|0032) = = "-233.242\-283.242\129.939 "
# (0020|0037) = = "1\-0\0\-0\1\0 "
# (0020|0052) = = "1.3.6.1.4.1.25403.88623636059514.16184.20181106044710.8"
# (0020|0060) = = ""
# (0020|1002) = = "116 "
# (0020|1040) = = ""
# (0020|1041) = = "129.9394531 "
# (0020|9056) = = "1 "
# (0020|9057) = = "43"
# (0028|0002) = = "1"
# (0028|0004) = = "MONOCHROME2 "
# (0028|0010) = = "512"
# (0028|0011) = = "512"
# (0028|0030) = = "0.8594\0.8594 "
# (0028|0100) = = "16"
# (0028|0101) = = "16"
# (0028|0102) = = "15"
# (0028|0103) = = "1"
# (0028|0106) = = "0"
# (0028|0107) = = "540"
# (0028|1050) = = "270 "
# (0028|1051) = = "540 "
# (0032|1032) = = "CHOPRA"
# (0040|0242) = = "MMR1OW"
# (0040|0243) = = "MMR1"
# (0040|0254) = = "MRI ABDOMEN WITH AND WITHOUT CONTRAST "

# %%
s1.index.equals(s6.index)
# Out:
# True

# %%
df = pd.DataFrame({'s1':s1, 's2':s2, 's5':s5, 's6':s6})

# %%
import seaborn

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    #df['result'] = np.where(df['s5'] == df['s6'], 'no change', 'changed')
    display(df)
# Out:
#                                                           s1  \
# 0008|0005                                         ISO_IR 100
# 0008|0008                             ORIGINAL\PRIMARY\OTHER
# 0008|0012                                                NaN
# 0008|0013                                                NaN
# 0008|0016                          1.2.840.10008.5.1.4.1.1.4
# 0008|0018  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0008|0020                                           20181106
# 0008|0021                                           20181106
# 0008|0022                                           20181106
# 0008|0023                                           20181106
# 0008|0030                                             070444
# 0008|0031
# 0008|0032                                             071221
# 0008|0033                                             071221
# 0008|0050
# 0008|0060                                                 MR
# 0008|0070                                 GE MEDICAL SYSTEMS
# 0008|0080
# 0008|0090
# 0008|1010
# 0008|1030                               Abd Abdom Contrast
# 0008|103e
# 0008|1090                                         Signa HDxt
# 0010|0010
# 0010|0020
# 0010|0030                                           19680101
# 0010|0040
# 0010|1010
# 0010|1030
# 0010|21b0
# 0018|0015
# 0018|0020                                                 SE
# 0018|0021                                                 SK
# 0018|0022  FAST_GEMS\EDR_GEMS\SS_GEMS\FILTERED_GEMS\ACC_G...
# 0018|0023                                                 2D
# 0018|0025                                                 N
# 0018|0050                                                 8
# 0018|0080                                           956.652
# 0018|0081                                           201.488
# 0018|0082                                                NaN
# 0018|0083                                             0.5625
# 0018|0084                                         63.863434
# 0018|0085                                                 1H
# 0018|0086                                                 1
# 0018|0087                                               1.5
# 0018|0088                                                 10
# 0018|0091                                                 1
# 0018|0093                                             56.25
# 0018|0094                                               100
# 0018|0095                                           651.016
# 0018|1000
# 0018|1020       23\LX\MR Software release:HD23.0_V02_1406.a
# 0018|1030                                             Liver
# 0018|1060                                                NaN
# 0018|1088                                                 0
# 0018|1090                                                 0
# 0018|1094                                                 0
# 0018|1100                                               440
# 0018|1250                                   8Ch Body FullFOV
# 0018|1310                                        256\0\0\160
# 0018|1312                                               COL
# 0018|1314                                                 90
# 0018|1315                                                 N
# 0018|1316                                           2.35506
# 0018|5100                                               FFS
# 0020|000d  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|000e  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|0010
# 0020|0011
# 0020|0012                                                 1
# 0020|0013                                                 8
# 0020|0032                           -236.797\-282.943\128.39
# 0020|0037                                     1\-0\0\-0\1\0
# 0020|0052  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|0060
# 0020|1002                                                 25
# 0020|1040
# 0020|1041                                       128.3897247
# 0020|9056                                                 1
# 0020|9057                                                  8
# 0028|0002                                                  1
# 0028|0004                                       MONOCHROME2
# 0028|0010                                                256
# 0028|0011                                                256
# 0028|0030                                     1.7188\1.7188
# 0028|0100                                                 16
# 0028|0101                                                 16
# 0028|0102                                                 15
# 0028|0103                                                  1
# 0028|0106                                                  0
# 0028|0107                                                650
# 0028|1050                                               325
# 0028|1051                                               650
# 0032|1032                                             CHOPRA
# 0040|0242                                             MMR1OW
# 0040|0243                                               MMR1
# 0040|0254             MRI ABDOMEN WITH AND WITHOUT CONTRAST
# 0070|0403                                                NaN
#
#                                                           s2  \
# 0008|0005                                         ISO_IR 100
# 0008|0008                             ORIGINAL\PRIMARY\OTHER
# 0008|0012                                                NaN
# 0008|0013                                                NaN
# 0008|0016                          1.2.840.10008.5.1.4.1.1.4
# 0008|0018  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0008|0020                                           20181106
# 0008|0021                                           20181106
# 0008|0022                                           20181106
# 0008|0023                                           20181106
# 0008|0030                                             070444
# 0008|0031
# 0008|0032                                             072102
# 0008|0033                                             072102
# 0008|0050
# 0008|0060                                                 MR
# 0008|0070                                 GE MEDICAL SYSTEMS
# 0008|0080
# 0008|0090
# 0008|1010
# 0008|1030                               Abd Abdom Contrast
# 0008|103e
# 0008|1090                                         Signa HDxt
# 0010|0010
# 0010|0020
# 0010|0030                                           19680101
# 0010|0040
# 0010|1010
# 0010|1030
# 0010|21b0
# 0018|0015
# 0018|0020                                                 GR
# 0018|0021                                             SS\SK
# 0018|0022  FAST_GEMS\SAT_GEMS\EDR_GEMS\FILTERED_GEMS\ACC_...
# 0018|0023                                                 3D
# 0018|0025                                                 N
# 0018|0050                                               4.6
# 0018|0080                                             3.848
# 0018|0081                                             1.796
# 0018|0082                                                 7
# 0018|0083                                           0.725806
# 0018|0084                                         63.863445
# 0018|0085                                                 1H
# 0018|0086                                                 1
# 0018|0087                                               1.5
# 0018|0088                                               2.3
# 0018|0091                                                 1
# 0018|0093                                           72.5807
# 0018|0094                                               100
# 0018|0095                                           244.141
# 0018|1000
# 0018|1020       23\LX\MR Software release:HD23.0_V02_1406.a
# 0018|1030                                             Liver
# 0018|1060                                                NaN
# 0018|1088                                                 0
# 0018|1090                                                 0
# 0018|1094                                                 0
# 0018|1100                                               440
# 0018|1250                                   8Ch Body FullFOV
# 0018|1310                                        288\0\0\160
# 0018|1312                                               COL
# 0018|1314                                                 12
# 0018|1315                                                 N
# 0018|1316                                           0.623342
# 0018|5100                                               FFS
# 0020|000d  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|000e  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|0010
# 0020|0011
# 0020|0012                                                 1
# 0020|0013                                                 82
# 0020|0032                         -233.242\-283.242\129.939
# 0020|0037                                     1\-0\0\-0\1\0
# 0020|0052  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|0060
# 0020|1002                                               116
# 0020|1040
# 0020|1041                                       129.9394531
# 0020|9056                                                 1
# 0020|9057                                                 43
# 0028|0002                                                  1
# 0028|0004                                       MONOCHROME2
# 0028|0010                                                512
# 0028|0011                                                512
# 0028|0030                                     0.8594\0.8594
# 0028|0100                                                 16
# 0028|0101                                                 16
# 0028|0102                                                 15
# 0028|0103                                                  1
# 0028|0106                                                  0
# 0028|0107                                                540
# 0028|1050                                               270
# 0028|1051                                               540
# 0032|1032                                             CHOPRA
# 0040|0242                                             MMR1OW
# 0040|0243                                               MMR1
# 0040|0254             MRI ABDOMEN WITH AND WITHOUT CONTRAST
# 0070|0403                                                NaN
#
#                                                           s5  \
# 0008|0005                                         ISO_IR 100
# 0008|0008         DERIVED\PRIMARY\MR_ELASTOGRAPHY\ELASTOGRAM
# 0008|0012
# 0008|0013
# 0008|0016                          1.2.840.10008.5.1.4.1.1.4
# 0008|0018  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0008|0020                                           20181106
# 0008|0021                                           20181106
# 0008|0022                                           20181106
# 0008|0023                                           20181106
# 0008|0030                                             070444
# 0008|0031
# 0008|0032                                             071531
# 0008|0033                                             072349
# 0008|0050
# 0008|0060                                                 MR
# 0008|0070                                 GE MEDICAL SYSTEMS
# 0008|0080
# 0008|0090
# 0008|1010
# 0008|1030                               Abd Abdom Contrast
# 0008|103e
# 0008|1090                                         Signa HDxt
# 0010|0010
# 0010|0020
# 0010|0030                                           19680101
# 0010|0040
# 0010|1010
# 0010|1030
# 0010|21b0
# 0018|0015
# 0018|0020                                                 RM
# 0018|0021                                               NONE
# 0018|0022         FC\SAT_GEMS\EDR_GEMS\SEQ_GEMS\ACC_GEMS\SP
# 0018|0023                                                 2D
# 0018|0025                                                NaN
# 0018|0050                                                 8
# 0018|0080                                             49.968
# 0018|0081                                             21.696
# 0018|0082                                                NaN
# 0018|0083                                                NaN
# 0018|0084                                         63.863476
# 0018|0085                                                NaN
# 0018|0086                                                 1
# 0018|0087                                               1.5
# 0018|0088                                                 11
# 0018|0091                                                 1
# 0018|0093                                                NaN
# 0018|0094                                                NaN
# 0018|0095                                           244.141
# 0018|1000                                                NaN
# 0018|1020       23\LX\MR Software release:HD23.0_V02_1406.a
# 0018|1030                                             Liver
# 0018|1060
# 0018|1088                                                NaN
# 0018|1090                                                 0
# 0018|1094                                                NaN
# 0018|1100                                           440.0128
# 0018|1250                                   8Ch Body FullFOV
# 0018|1310                                         256\0\0\64
# 0018|1312                                               COL
# 0018|1314                                                 30
# 0018|1315                                                NaN
# 0018|1316                                                NaN
# 0018|5100                                               FFS
# 0020|000d  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|000e  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|0010
# 0020|0011
# 0020|0012                                                NaN
# 0020|0013                                                 4
# 0020|0032                         -227.259\-279.155\130.736
# 0020|0037                                     1\-0\0\-0\1\0
# 0020|0052  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|0060
# 0020|1002                                                 32
# 0020|1040
# 0020|1041                                       130.7358856
# 0020|9056                                                NaN
# 0020|9057                                                NaN
# 0028|0002                                                  1
# 0028|0004                                       MONOCHROME2
# 0028|0010                                                256
# 0028|0011                                                256
# 0028|0030                                     1.7188\1.7188
# 0028|0100                                                 16
# 0028|0101                                                 16
# 0028|0102                                                 15
# 0028|0103                                                  1
# 0028|0106                                                  0
# 0028|0107                                              26886
# 0028|1050                                               9421
# 0028|1051                                             12875
# 0032|1032                                             CHOPRA
# 0040|0242                                                NaN
# 0040|0243                                                NaN
# 0040|0254                                                NaN
# 0070|0403                                                0.5
#
#                                                           s6
# 0008|0005                                         ISO_IR 100
# 0008|0008         DERIVED\PRIMARY\MR_ELASTOGRAPHY\ELASTOGRAM
# 0008|0012
# 0008|0013
# 0008|0016                          1.2.840.10008.5.1.4.1.1.4
# 0008|0018  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0008|0020                                           20181106
# 0008|0021                                           20181106
# 0008|0022                                           20181106
# 0008|0023                                           20181106
# 0008|0030                                             070444
# 0008|0031
# 0008|0032                                             071531
# 0008|0033                                             072351
# 0008|0050
# 0008|0060                                                 MR
# 0008|0070                                 GE MEDICAL SYSTEMS
# 0008|0080
# 0008|0090
# 0008|1010
# 0008|1030                               Abd Abdom Contrast
# 0008|103e
# 0008|1090                                         Signa HDxt
# 0010|0010
# 0010|0020
# 0010|0030                                           19680101
# 0010|0040
# 0010|1010
# 0010|1030
# 0010|21b0
# 0018|0015
# 0018|0020                                                 RM
# 0018|0021                                               NONE
# 0018|0022         FC\SAT_GEMS\EDR_GEMS\SEQ_GEMS\ACC_GEMS\SP
# 0018|0023                                                 2D
# 0018|0025                                                NaN
# 0018|0050                                                 8
# 0018|0080                                             49.968
# 0018|0081                                             21.696
# 0018|0082                                                NaN
# 0018|0083                                                NaN
# 0018|0084                                         63.863476
# 0018|0085                                                NaN
# 0018|0086                                                 1
# 0018|0087                                               1.5
# 0018|0088                                                 11
# 0018|0091                                                 1
# 0018|0093                                                NaN
# 0018|0094                                                NaN
# 0018|0095                                           244.141
# 0018|1000                                                NaN
# 0018|1020       23\LX\MR Software release:HD23.0_V02_1406.a
# 0018|1030                                             Liver
# 0018|1060
# 0018|1088                                                NaN
# 0018|1090                                                 0
# 0018|1094                                                NaN
# 0018|1100                                           440.0128
# 0018|1250                                   8Ch Body FullFOV
# 0018|1310                                         256\0\0\64
# 0018|1312                                               COL
# 0018|1314                                                 30
# 0018|1315                                                NaN
# 0018|1316                                                NaN
# 0018|5100                                               FFS
# 0020|000d  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|000e  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|0010
# 0020|0011
# 0020|0012                                                NaN
# 0020|0013                                                 4
# 0020|0032                         -227.259\-279.155\130.736
# 0020|0037                                     1\-0\0\-0\1\0
# 0020|0052  1.3.6.1.4.1.25403.88623636059514.16184.2018110...
# 0020|0060
# 0020|1002                                                 32
# 0020|1040
# 0020|1041                                       130.7358856
# 0020|9056                                                NaN
# 0020|9057                                                NaN
# 0028|0002                                                  1
# 0028|0004                                       MONOCHROME2
# 0028|0010                                                256
# 0028|0011                                                256
# 0028|0030                                     1.7188\1.7188
# 0028|0100                                                 16
# 0028|0101                                                 16
# 0028|0102                                                 15
# 0028|0103                                                  1
# 0028|0106                                                  0
# 0028|0107                                              26886
# 0028|1050                                               9617
# 0028|1051                                             12514
# 0032|1032                                             CHOPRA
# 0040|0242                                                NaN
# 0040|0243                                                NaN
# 0040|0254                                                NaN
# 0070|0403                                                0.5

# %% [markdown]
# # Visualization of the images

# %%
for j in range(0,4):
    fig, axs = plt.subplots(2, 3, constrained_layout=True)
    axs = axs.flatten()
    for i,fn in enumerate(['SE00001','SE00002','SE00003','SE00004','SE00005','SE00006']):
        img = sitk.ReadImage(temp_data_dir + '/' + fn + '.nii')
        IMG = sitk.GetArrayFromImage(img)

        axs[i].imshow(IMG[j,:,:],cmap='viridis')
        axs[i].set_title(fn)
plt.show()

# %%
for subj in ['396','399','402','403','404','405','406']:
    data_dir = full_data_dir + f'/{subj}/DICOM/ST00001'
    for fn in subdir_names:
        print( "Reading Dicom directory:", data_dir )
        reader = sitk.ImageSeriesReader()

        dicom_names = reader.GetGDCMSeriesFileNames( data_dir + '/' + fn )
        reader.SetFileNames(dicom_names)

        image = reader.Execute()

        size = image.GetSize()
        print( "Image size:", size[0], size[1], size[2] )

        print( "Writing image:", data_dir + '/' + fn + '.nii' )

        sitk.WriteImage( image, data_dir + '/' + fn + '.nii' )

# %%
subjects = ['396','399','402','403','404','405','406']
images = []
for subj in subjects:
    images.append([])
    data_dir = f'/pghbio/dbmi/batmanlab/bpollack/predictElasticity/data/MRE/{subj}/DICOM/ST00001'
    #fig, axs = plt.subplots(2, 3, constrained_layout=True)
    #axs = axs.flatten()
    for i,fn in enumerate(subdir_names):
        img = sitk.ReadImage(data_dir + '/' + fn + '.nii')
        IMG = skim.transform.resize(sitk.GetArrayFromImage(img), (4,256,256))
        images[-1].append(IMG)
        

        #axs[i].imshow(IMG[0,:,:],cmap='viridis')
        #axs[i].set_title(fn)
#plt.show()
#ds = xr.Dataset({'images': (['images)
images = np.asarray(images)
# Out:
# /home/bpollack/conda_envs/mre/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
images.shape

# %%
ds = xr.Dataset({'images': (['subject', 'mode', 'slice', 'y', 'x'], images)},
               coords={'subject': subjects,
                      'mode':subdir_names})

# %%
ds.sel(subject='405', slice=2, mode='SE00001').to_array()[0].shape
# Out:
# (256, 256)

# %%
#fig, axs = plt.subplots(2, 2, constrained_layout=True)
#axs = axs.flatten()
#plt.figure(figsize=(10,8))
#ds.sel(subject='402', mode='SE00005', drop=True).to_array().plot(col='slice', col_wrap=2, figsize=(15,13), robust=True)
ds.sel(subject='402', slice=1, mode='SE00005', drop=True).to_array().shape
# Out:
# (1, 256, 256)

# %% [markdown]
# # Separating Confident Area

# %%
subj='396'
data_dir = f'/pghbio/dbmi/batmanlab/bpollack/predictElasticity/data/MRE/{subj}/DICOM/ST00001'

fn = 'SE00005'
img1 = sitk.ReadImage(data_dir+ '/' + fn + '.nii')
IMG1 = sitk.GetArrayFromImage(img1)

fn = 'SE00006'
img2 = sitk.ReadImage(data_dir+ '/' + fn + '.nii')
IMG2 = sitk.GetArrayFromImage(img2)

# %%
fig, axs = plt.subplots(1, 3, constrained_layout=True)
axs = axs.flatten()
axs[0].imshow(IMG1[0,:,:])
axs[1].imshow(IMG2[0,:,:])
diffIMG = IMG1 - IMG2
axs[2].imshow(diffIMG[0,:,:])

# %%
# Compute the Canny filter for two values of sigma
im = IMG1[0,:,:]
edges1 = feature.canny(im)
edges2 = feature.canny(im, sigma=0.2)

# display results
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, constrained_layout=True,
                                    sharex=True, sharey=True)

ax1.imshow(im, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('noisy image', fontsize=20)

ax2.imshow(edges1, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title('Canny filter, $\sigma=1$', fontsize=20)

ax3.imshow(edges2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Canny filter, $\sigma=3$', fontsize=20)
plt.show()

# %%
plt.figure()
plt.imshow(IMG1[0,100:120,50:70],cmap='gray')

# %%
IMG1.max()

# %%
tmpIMG = IMG1.copy()
#tmpIMG[tmpIMG==0] = IMG1.max() + 1
plt.figure()
plt.imshow(tmpIMG[0,100:120,50:70],cmap='gray')
plt.figure()
plt.imshow(tmpIMG[0,100:104,50:54],cmap='gray')

# %%
from skimage.feature import match_template

pat = tmpIMG[0,100:108,50:58]
result = match_template(tmpIMG[0,:,:], pat,pad_input=True)
plt.figure()
plt.imshow(result)

plt.figure()
plt.imshow(result > 0.3)

# %%
from skimage import morphology

mask = result > 0.3
b = morphology.remove_small_holes(mask, 1, connectivity=1)
plt.figure()
plt.imshow(b)

# %%
result.shape

# %%
b = morphology.binary_dilation(mask)
#b = morphology.binary_erosion(mask)
#b = morphology.binary_dilation(b)
plt.figure()
plt.imshow(b)

# %%
c = morphology.remove_small_holes(b, 2, connectivity=1)
c = morphology.binary_erosion(c)
plt.figure()
plt.imshow(c)

# %%
from scipy.ndimage.morphology import binary_fill_holes

# %%
c = binary_fill_holes(b)
plt.figure()
plt.imshow(c)

# %%
pat

# %% [markdown]
# # Define Pre-processing pipeline
# Put everything together and define a pre-processing pipeline.

# %%
def makeUncertainMask(inFn, maskFn, thr=0.3):
    from skimage import morphology
    from scipy.ndimage.morphology import binary_fill_holes
    from skimage.feature import match_template
    import SimpleITK as sitk

    
    pat = np.array([[5987, 6735,    0,    0, 7704, 8073,    0,    0],
       [4753, 5325,    0,    0, 6413, 6839,    0,    0],
       [   0,    0, 5333, 4610,    0,    0, 5689, 5382],
       [   0,    0, 5109, 3999,    0,    0, 4388, 4378],
       [3745, 3950,    0,    0, 2742, 3430,    0,    0],
       [4156, 3672,    0,    0, 3127, 3230,    0,    0],
       [   0,    0, 3092, 3279,    0,    0, 2812, 2309],
       [   0,    0, 2928, 3069,    0,    0, 1984, 2017]], dtype=np.int16)
    
    img = sitk.ReadImage(inFn)
    IMG = sitk.GetArrayFromImage(img)
    MASK3d = np.zeros(IMG.shape)
    
    for cnt in range(IMG.shape[0]):
        # find the checkboard pattern
        result = match_template(tmpIMG[cnt,:,:], pat, pad_input=True)
        
        # make a mask
        mask = result > thr
        
        # 2 dialations followed by filling  holes
        b = morphology.binary_dilation(mask)
        c = morphology.remove_small_holes(b, 2, connectivity=1)
        d = morphology.binary_erosion(c)
        #d = morphology.binary_dilation(c)
        
        MASK3d[cnt,:,:] = binary_fill_holes(d)
        
    # save the results
    mask3d = sitk.GetImageFromArray(MASK3d)
    mask3d.SetDirection(img.GetDirection())
    mask3d.SetSpacing(img.GetSpacing())
    mask3d.SetOrigin(img.GetOrigin())
    
    sitk.WriteImage(mask3d,maskFn)

# %%
makeUncertainMask(temp_data_dir + '/' + fn + '.nii', 
                  temp_data_dir + '/' + 'uncertainMask' + '.nii', thr=0.3)

# %%
testimg = sitk.ReadImage(temp_data_dir+ '/' + 'uncertainMask' + '.nii')
testIMG = sitk.GetArrayFromImage(testimg)

# %%
plt.figure()
plt.imshow(testIMG[1,:,:])

# %%
imshow(IMG1[1,:,:])

# %%
IMG.shape

# %%
b.shape

# %%
mask.shape

# %%
result.shape

# %%
match_template?
