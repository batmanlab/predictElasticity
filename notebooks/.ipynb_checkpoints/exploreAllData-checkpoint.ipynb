# %%
from __future__ import print_function

import SimpleITK as sitk
import sys, os
import numpy as np
import glob

import matplotlib.pyplot as plt

from scipy import ndimage as ndi
from skimage import feature
from skimage.feature import match_template
from scipy.ndimage.morphology import binary_fill_holes

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def makeUncertainMask(inFn, maskFn, thr=0.3):
    from skimage import morphology
    from scipy.ndimage.morphology import binary_fill_holes
    from skimage.feature import match_template
    import SimpleITK as sitk

    
    pat = array([[5987, 6735,    0,    0, 7704, 8073,    0,    0],
       [4753, 5325,    0,    0, 6413, 6839,    0,    0],
       [   0,    0, 5333, 4610,    0,    0, 5689, 5382],
       [   0,    0, 5109, 3999,    0,    0, 4388, 4378],
       [3745, 3950,    0,    0, 2742, 3430,    0,    0],
       [4156, 3672,    0,    0, 3127, 3230,    0,    0],
       [   0,    0, 3092, 3279,    0,    0, 2812, 2309],
       [   0,    0, 2928, 3069,    0,    0, 1984, 2017]], dtype=int16)
    
    img = sitk.ReadImage(inFn)
    IMG = sitk.GetArrayFromImage(img)
    MASK3d = np.zeros(IMG.shape)
    
    for cnt in range(IMG.shape[0]):
        # find the checkboard pattern
        result = match_template(tmpIMG[cnt,:,:], pat, pad_input=True)
        
        # make a mask
        mask = result > thr
        
        # 2 dialations followed by filling  holes
        b = morphology.binary_dilation(mask)
        c = morphology.remove_small_holes(b, 2, connectivity=1)
        d = morphology.binary_erosion(c)
        #d = morphology.binary_dilation(c)
        
        MASK3d[cnt,:,:] = binary_fill_holes(d)
        
    # save the results
    mask3d = sitk.GetImageFromArray(MASK3d)
    mask3d.SetDirection(img.GetDirection())
    mask3d.SetSpacing(img.GetSpacing())
    mask3d.SetOrigin(img.GetOrigin())
    
    sitk.WriteImage(mask3d,maskFn)

# %%
dataRoot = '/Users/kayhan/Downloads/drive-download-20181110T181841Z-001'

# %% [markdown]
# # Convert Dicom to Nifti

# %%
for subjDir in glob.glob(dataRoot + "/*/"):
    subID = subjDir.split('/')[-2]
    tempDicomDir = subjDir + '/DICOM/ST00001'
    tempNiftiDir = subjDir + '/Nifti'
    if not(os.path.exists(tempNiftiDir)):
        os.mkdir(tempNiftiDir)
    
    for fn,modName in [('SE00001','T2SS'),
                       ('SE00002','T1Pre'),
                       ('SE00003','T1Pos'),
                       ('SE00004','T2FR'),
                       ('SE00005', 'elast'),
                       ('SE00006','elastMsk')]:
        print( "Reading Dicom directory:",  tempDicomDir + '/' + fn )
        reader = sitk.ImageSeriesReader()

        dicom_names = reader.GetGDCMSeriesFileNames( tempDicomDir + '/' + fn )
        reader.SetFileNames(dicom_names)

        image = reader.Execute()

        size = image.GetSize()
        dims = image.GetSpacing()
        print( "Image size:", size[0], size[1], size[2] )
        print( "Image dims:", dims[0], dims[1], dims[2] )


        print( "Writing image:", tempNiftiDir + '/' + subID + '_%s'%modName + '.nii' )

        sitk.WriteImage( image, tempNiftiDir + '/' + subID + '_%s'%modName + '.nii' )
# Out:
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/391//DICOM/ST00001/SE00001
# Image size: 512 512 4
# Image dims: 0.7422 0.7422 11.5
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001
nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/381//DICOM/ST00001/SE00006
# Image size: 256 256 4
# Image dims: 1.6406 1.6406 11.0
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/381//Nifti/381_elastMsk.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//DICOM/ST00001/SE00001
# Image size: 256 256 4
# Image dims: 1.4063 1.4063 12.000001907348633
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//Nifti/386_T2SS.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//DICOM/ST00001/SE00002
# Image size: 512 512 4
# Image dims: 0.7031 0.7031 11.500001907348633
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//Nifti/386_T1Pre.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//DICOM/ST00001/SE00003
# Image size: 512 512 4
# Image dims: 0.7031 0.7031 11.500001907348633
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//Nifti/386_T1Pos.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//DICOM/ST00001/SE00004
# Image size: 512 512 4
# Image dims: 0.7031 0.7031 18.000001907348633
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//Nifti/386_T2FR.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//DICOM/ST00001/SE00005
# Image size: 256 256 4
# Image dims: 1.4063 1.4063 11.000001907348633
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//Nifti/386_elast.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//DICOM/ST00001/SE00006
# Image size: 256 256 4
# Image dims: 1.4063 1.4063 11.000001907348633
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/386//Nifti/386_elastMsk.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//DICOM/ST00001/SE00001
# Image size: 512 512 4
# Image dims: 0.7422 0.7422 11.5
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//Nifti/372_T2SS.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//DICOM/ST00001/SE00002
# Image size: 512 512 4
# Image dims: 0.7422 0.7422 11.5
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//Nifti/372_T1Pre.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//DICOM/ST00001/SE00003
# Image size: 256 256 4
# Image dims: 1.5625 1.5625 10.0
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//Nifti/372_T1Pos.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//DICOM/ST00001/SE00004
# Image size: 256 256 4
# Image dims: 1.5625 1.5625 9.0
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//Nifti/372_T2FR.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//DICOM/ST00001/SE00005
# Image size: 256 256 4
# Image dims: 1.4453 1.4453 11.0
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//Nifti/372_elast.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//DICOM/ST00001/SE00006
# Image size: 256 256 4
# Image dims: 1.4453 1.4453 11.0
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/372//Nifti/372_elastMsk.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//DICOM/ST00001/SE00001
# Image size: 512 512 4
# Image dims: 0.7031 0.7031 11.500009536743164
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//Nifti/388_T2SS.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//DICOM/ST00001/SE00002
# Image size: 512 512 4
# Image dims: 0.7031 0.7031 11.50001049041748
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//Nifti/388_T1Pre.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//DICOM/ST00001/SE00003
# Image size: 256 256 4
# Image dims: 1.4063 1.4063 10.000040054321289
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//Nifti/388_T1Pos.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//DICOM/ST00001/SE00004
# Image size: 256 256 4
# Image dims: 1.4063 1.4063 9.00005054473877
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//Nifti/388_T2FR.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//DICOM/ST00001/SE00005
# Image size: 256 256 4
# Image dims: 1.4063 1.4063 11.000040054321289
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//Nifti/388_elast.nii
# Reading Dicom directory: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//DICOM/ST00001/SE00006
# Image size: 256 256 4
# Image dims: 1.4063 1.4063 11.000040054321289
# Writing image: /Users/kayhan/Downloads/drive-download-20181110T181841Z-001/388//Nifti/388_elastMsk.nii

# %% [markdown]
# # Visualization of the images

# %%
for subjDir in glob.glob(dataRoot + "/*/"):
    subID = subjDir.split('/')[-2]
    tempDicomDir = subjDir + '/DICOM/ST00001'
    tempNiftiDir = subjDir + '/Nifti'
    figure(figsize=(15,75))
    subplot(1,6,1)
    cnt = 0
    
    for fn,modName in [('SE00001','T2SS'),
                       ('SE00002','T1Pre'),
                       ('SE00003','T1Pos'),
                       ('SE00004','T2FR'),
                       ('SE00005', 'elast'),
                       ('SE00006','elastMsk')]:
        
        cnt = cnt + 1
        subplot(1,6,cnt)
        img = sitk.ReadImage(tempNiftiDir + '/' + subID + '_%s'%modName + '.nii')
        IMG = sitk.GetArrayFromImage(img)

        imshow(IMG[0,:,:],cmap='gray')
# Out:
# /Users/kayhan/anaconda2/envs/py36Torch/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %%
for subj in ['396','399','402','403','404','405','406']:
    tempDataDir = '/Users/kayhan/Downloads/%s/DICOM/ST00001'%subj
    figure(figsize=(15,75))
    subplot(1,6,1)
    cnt = 0
    for fn in ['SE00001','SE00002','SE00003','SE00004','SE00005','SE00006']:
        cnt = cnt + 1
        subplot(1,6,cnt)
        img = sitk.ReadImage(tempDataDir + '/' + fn + '.nii')
        IMG = sitk.GetArrayFromImage(img)

        imshow(IMG[0,:,:],cmap='gray')
# Out:
# /Users/kayhan/anaconda2/envs/py36Torch/lib/python3.6/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "

# %% [markdown]
# # Separating Confident Area

# %%
subj='396'
tempDataDir = '/Users/kayhan/Downloads/%s/DICOM/ST00001'%subj

fn = 'SE00005'
img1 = sitk.ReadImage(tempDataDir + '/' + fn + '.nii')
IMG1 = sitk.GetArrayFromImage(img1)

fn = 'SE00006'
img2 = sitk.ReadImage(tempDataDir + '/' + fn + '.nii')
IMG2 = sitk.GetArrayFromImage(img2)

# %%
figure()
imshow(IMG1[0,:,:])

figure()
imshow(IMG2[0,:,:])

figure()
diffIMG = IMG1 - IMG2
imshow(diffIMG[0,:,:])

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage as ndi

from skimage import feature



# Compute the Canny filter for two values of sigma
im = IMG1[0,:,:]
edges1 = feature.canny(im)
edges2 = feature.canny(im, sigma=0.2)

# display results
fig, (ax1, ax2, ax3) = plt.subplots(nrows=1, ncols=3, figsize=(8, 3),
                                    sharex=True, sharey=True)

ax1.imshow(im, cmap=plt.cm.gray)
ax1.axis('off')
ax1.set_title('noisy image', fontsize=20)

ax2.imshow(edges1, cmap=plt.cm.gray)
ax2.axis('off')
ax2.set_title('Canny filter, $\sigma=1$', fontsize=20)

ax3.imshow(edges2, cmap=plt.cm.gray)
ax3.axis('off')
ax3.set_title('Canny filter, $\sigma=3$', fontsize=20)

fig.tight_layout()

plt.show()

# %%
plt.imshow(IMG1[0,100:120,50:70],cmap='gray')

# %%
IMG1.max()
# Out:
# 15633

# %%
tmpIMG = IMG1.copy()
#tmpIMG[tmpIMG==0] = IMG1.max() + 1
plt.imshow(tmpIMG[0,100:120,50:70],cmap='gray')

figure()
plt.imshow(tmpIMG[0,100:104,50:54],cmap='gray')

# %%
from skimage.feature import match_template

pat = tmpIMG[0,100:108,50:58]
result = match_template(tmpIMG[0,:,:], pat,pad_input=True)

imshow(result)

figure()
imshow(result > 0.3)

# %%
from skimage import morphology

mask = result > 0.3
b = morphology.remove_small_holes(mask, 1, connectivity=1)
imshow(b)

# %%
result.shape
# Out:
# (256, 256)

# %%
b = morphology.binary_dilation(mask)
#b = morphology.binary_erosion(mask)
#b = morphology.binary_dilation(b)

imshow(b)

# %%
c = morphology.remove_small_holes(b, 2, connectivity=1)
c = morphology.binary_erosion(c)
imshow(c)

# %%
from scipy.ndimage.morphology import binary_fill_holes

# %%
c = binary_fill_holes(b)
imshow(c)

# %%
pat
# Out:
# array([[5987, 6735,    0,    0, 7704, 8073,    0,    0],
#        [4753, 5325,    0,    0, 6413, 6839,    0,    0],
#        [   0,    0, 5333, 4610,    0,    0, 5689, 5382],
#        [   0,    0, 5109, 3999,    0,    0, 4388, 4378],
#        [3745, 3950,    0,    0, 2742, 3430,    0,    0],
#        [4156, 3672,    0,    0, 3127, 3230,    0,    0],
#        [   0,    0, 3092, 3279,    0,    0, 2812, 2309],
#        [   0,    0, 2928, 3069,    0,    0, 1984, 2017]], dtype=int16)

# %% [markdown]
# # Define Pre-processing pipeline
# Put everything together and define a pre-processing pipeline.

# %%
def makeUncertainMask(inFn, maskFn, thr=0.3):
    from skimage import morphology
    from scipy.ndimage.morphology import binary_fill_holes
    from skimage.feature import match_template
    import SimpleITK as sitk

    
    pat = array([[5987, 6735,    0,    0, 7704, 8073,    0,    0],
       [4753, 5325,    0,    0, 6413, 6839,    0,    0],
       [   0,    0, 5333, 4610,    0,    0, 5689, 5382],
       [   0,    0, 5109, 3999,    0,    0, 4388, 4378],
       [3745, 3950,    0,    0, 2742, 3430,    0,    0],
       [4156, 3672,    0,    0, 3127, 3230,    0,    0],
       [   0,    0, 3092, 3279,    0,    0, 2812, 2309],
       [   0,    0, 2928, 3069,    0,    0, 1984, 2017]], dtype=int16)
    
    img = sitk.ReadImage(inFn)
    IMG = sitk.GetArrayFromImage(img)
    MASK3d = np.zeros(IMG.shape)
    
    for cnt in range(IMG.shape[0]):
        # find the checkboard pattern
        result = match_template(tmpIMG[cnt,:,:], pat, pad_input=True)
        
        # make a mask
        mask = result > thr
        
        # 2 dialations followed by filling  holes
        b = morphology.binary_dilation(mask)
        c = morphology.remove_small_holes(b, 2, connectivity=1)
        d = morphology.binary_erosion(c)
        #d = morphology.binary_dilation(c)
        
        MASK3d[cnt,:,:] = binary_fill_holes(d)
        
    # save the results
    mask3d = sitk.GetImageFromArray(MASK3d)
    mask3d.SetDirection(img.GetDirection())
    mask3d.SetSpacing(img.GetSpacing())
    mask3d.SetOrigin(img.GetOrigin())
    
    sitk.WriteImage(mask3d,maskFn)

# %%
makeUncertainMask(tempDataDir + '/' + fn + '.nii', 
                  tempDataDir + '/' + 'uncertainMask' + '.nii', thr=0.3)

# %%
testimg = sitk.ReadImage(tempDataDir + '/' + 'uncertainMask' + '.nii')
testIMG = sitk.GetArrayFromImage(testimg)

# %%
imshow(testIMG[2,:,:])

# %%
imshow(IMG1[2,:,:])

# %%
IMG.shape
# Out:
# (4, 256, 256)

# %%
b.shape
# Out:
# (249, 249)

# %%
mask.shape
# Out:
# (249, 249)

# %%
result.shape
# Out:
# (249, 249)

# %%
match_template?
