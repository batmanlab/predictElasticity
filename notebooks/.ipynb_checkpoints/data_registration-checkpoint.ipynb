# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (10,8)
import SimpleITK as sitk
import sys, os
import numpy as np
import pandas as pd
import xarray as xr
import pickle as pkl
from mre.preprocessing import MREDataset
from mre.mask import add_elast_mask
from mre.registration import MRELiverMask
from mre.registration import add_liver_mask 
from mre.plotting import display_images_with_alpha
from ipywidgets import interact, fixed
from IPython.display import clear_output
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Some Notes:
# Using the T1Dual atlas with the T2SS fixed seems like it produces very good results.  The ring of fat helps anchor the images together and leads to a better liver ID

# %% [markdown]
# Aggregate the moving image data, sort it, and put it into a single itk object.

# %%
ls /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/
# Out:
# 1/  10/  13/  15/  19/  2/  20/  3/  5/  8/  notes.txt*  test.txt

# %%
ls /pghbio/dbmi/batmanlab/bpollack/predictElasticity/data/MRE/
# Out:
# 148/  220/  296/  354/  370/  388/  405/                   mre_ds_transform_2.p
# 162/  222/  299/  357/  371/  391/  406/                   mre_part2.zip
# 163/  239/  302/  358/  372/  394/  data_preprocess_v1.nc
# 178/  264/  331/  360/  375/  396/  mre_ds_1.p
# 189/  280/  332/  361/  380/  399/  mre_ds_preprocess_1.p
# 195/  289/  343/  363/  381/  402/  mre_ds_preprocess_2.p
# 197/  292/  350/  365/  383/  403/  mre_ds_preprocess_3.p
# 218/  295/  351/  368/  386/  404/  mre_ds_transform_1.p

# %%
mask_maker = MRELiverMask('296', '5', verbose=True, center=True, fixed_seq='T1Pre', moving_seq='T1_outphase')
# Out:
#   File "<ipython-input-27-600b6367e622>", line 1
#     mask_maker = MRELiverMask('296', '5', verbose=True, center=True, fixed_seq='T1Pre', moving_seq='T1_outphase)
#                                                                                                                 ^
# SyntaxError: EOL while scanning string literal

# %%
plt.figure()
interact(display_images_with_alpha, image_z=(0, mask_maker.moving_img.GetSize()[2]-1),
         alpha=(0.0,1.0,0.05), fixed = fixed(mask_maker.moving_img),
         moving=fixed(mask_maker.moving_mask))
plt.figure()
# Out:
# interactive(children=(IntSlider(value=14, description='image_z', max=29), FloatSlider(value=0.5, description='alpha', max=1.0, step=0.05), Output()), _dom_classes=('widget-interact',))

# %%
fig, axs = plt.subplots(1, 3, constrained_layout=True, sharex=True, sharey=True)
axs = axs.flatten()
axs[0].imshow(sitk.GetArrayFromImage(mask_maker.fixed_img)[0])
axs[1].imshow(sitk.GetArrayFromImage(mask_maker.moving_img)[22])
axs[2].imshow(sitk.GetArrayFromImage(mask_maker.moving_mask)[22])

# %% [markdown]
# Now let's interpolate everything so we're dealing with the same dimensions.

# %% [markdown]
# # Registration

# %% [markdown]
# Going to copy and paste in some methods from simpleITK notebook, attempt basic registration.

# %%
mask_maker.gen_param_map()

# %%
mask_maker.register_imgs()

# %%
mask_maker.gen_mask(smooth=True)

# %%
#interact(display_images_with_alpha, image_z=(0, fixed_image.GetSize()[2]-1), alpha=(0.0,1.0,0.05), fixed = fixed(fixed_image), moving=fixed(seg_image));
plt.figure()
interact(display_images_with_alpha, image_z=(0, mask_maker.moving_img.GetSize()[2]-1),
         alpha=(0.0,1.0,0.05), fixed = fixed(mask_maker.moving_img),
         moving=fixed(mask_maker.moving_mask))
plt.figure()
interact(display_images_with_alpha, image_z=(0, mask_maker.fixed_img.GetSize()[2]-1),
         alpha=(0.0,1.0,0.05), fixed = fixed(mask_maker.fixed_img),
         moving=fixed(mask_maker.moving_mask_result))
plt.figure()
interact(display_images_with_alpha, image_z=(0, mask_maker.fixed_img.GetSize()[2]-1),
         alpha=(0.0,1.0,0.05), fixed = fixed(mask_maker.fixed_img),
         moving=fixed(mask_maker.moving_img_result))
# Out:
# interactive(children=(IntSlider(value=14, description='image_z', max=29), FloatSlider(value=0.5, description='alpha', max=1.0, step=0.05), Output()), _dom_classes=('widget-interact',))
# interactive(children=(IntSlider(value=1, description='image_z', max=3), FloatSlider(value=0.5, description='alpha', max=1.0, step=0.05), Output()), _dom_classes=('widget-interact',))
# interactive(children=(IntSlider(value=1, description='image_z', max=3), FloatSlider(value=0.5, description='alpha', max=1.0, step=0.05), Output()), _dom_classes=('widget-interact',))
# <function mre.plotting.display_images_with_alpha>

# %%
tmp_mask_res = sitk.GetArrayFromImage(mask_maker.moving_mask_result)
tmp_mask = sitk.GetArrayFromImage(mask_maker.moving_mask)

# %%
full_data_dir = '/pghbio/dbmi/batmanlab/bpollack/predictElasticity/data/MRE/'
ds = pkl.load(open(full_data_dir+'mre_ds_preprocess_2.p', 'rb'))

# %%
ds = add_liver_mask(ds)
# Out:
# 100%|██████████| 50/50 [24:39<00:00, 29.55s/it]

# %%
pkl.dump(ds, open(full_data_dir+'mre_ds_preprocess_3.p', 'wb'), protocol=-1)

# %%
ds.sequence
# Out:
# <xarray.DataArray 'sequence' (sequence: 10)>
# array(['T1Pre', 'T1Pos', 'T2FR', 'T2SS', 'elastMsk', 'elast', 'msk',
#        'liverMsk', 'extra2', 'extra3'], dtype='<U8')
# Coordinates:
#   * sequence  (sequence) <U8 'T1Pre' 'T1Pos' 'T2FR' ... 'extra2' 'extra3'

# %%
from mre.plotting import grid_plots

# %%
good_seq = ['T1Pre', 'T1Pos', 'T2SS', 'T2FR', 'liverMsk', 'elast']
ds_tmp = ds.sel(sequence=good_seq, z=0)
#ds_tmp = ds.sel(sequence=good_seq, z=0, )
fig, axs = grid_plots(ds_tmp, 'subject', 'sequence', title='Liver Mask Comparison')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-070d6b16998d> in <module>()
#       1 good_seq = ['T1Pre', 'T1Pos', 'T2SS', 'T2FR', 'liverMsk', 'elast']
# ----> 2 ds_tmp = ds.sel(sequence=good_seq, z=0)
#       3 #ds_tmp = ds.sel(sequence=good_seq, z=0, )
#       4 fig, axs = grid_plots(ds_tmp, 'subject', 'sequence', title='Liver Mask Comparison')
#
# NameError: name 'ds' is not defined

# %%
from mre.preprocessing import make_nifti_atlas

# %%
make_nifti_atlas()
# Out:
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/1/T1DUAL//DICOM_anon/*dcm
# Image size: 256 256 35
# Image dims: 1.89453125 1.89453125 5.5
# Image orig: -232.99694347381 -238.76329636573 -39.239204406738
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/1/T1DUAL//DICOM_anon/*dcm
# Image size: 256 256 35
# Image dims: 1.89453125 1.89453125 5.5
# Image orig: -232.99694347381 -238.76329636573 -33.739204406738
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/1/T2SPIR//DICOM_anon/*dcm
# Image size: 256 256 36
# Image dims: 1.54296875 1.54296875 7.7
# Image orig: -192.65368556976 -192.7957458496 -61.692161560058
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/2/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 26
# Image dims: 1.44097220897674 1.44097220897674 9.0
# Image orig: -189.56485649945 -242.46268653869 -58.469701780269
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/2/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 26
# Image dims: 1.44097220897674 1.44097220897674 9.0
# Image orig: -189.52186676862 -242.46268653869 -49.469800962398
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/2/T2SPIR//DICOM_anon/*dcm
# Image size: 320 320 26
# Image dims: 1.359375 1.359375 9.0
# Image orig: -200.31831702589 -252.46268844604 -32.86616835976
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/3/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 30
# Image dims: 1.44097220897674 1.44097220897674 9.0
# Image orig: -185.04817581176 -219.65718841552 -55.777503967285
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/3/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 30
# Image dims: 1.44097220897674 1.44097220897674 9.0
# Image orig: -185.04817581176 -219.65718841552 -46.777503967285
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/3/T2SPIR//DICOM_anon/*dcm
# Image size: 320 320 30
# Image dims: 1.359375 1.359375 9.0
# Image orig: -195.04817771911 -229.65719032287 -37.777503967285
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/5/T1DUAL//DICOM_anon/*dcm
# Image size: 256 256 30
# Image dims: 1.69921875 1.69921875 9.0
# Image orig: -223.20717573165 -235.50464630126 -157.84902954101
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/5/T1DUAL//DICOM_anon/*dcm
# Image size: 256 256 30
# Image dims: 1.69921875 1.69921875 9.0
# Image orig: -223.20717573165 -235.50464630126 -148.84902954101
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/5/T2SPIR//DICOM_anon/*dcm
# Image size: 256 256 30
# Image dims: 1.66015625 1.66015625 9.0
# Image orig: -218.20717573165 -230.50464630126 -125.58109283447
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/8/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 36
# Image dims: 1.44097220897674 1.44097220897674 6.0
# Image orig: -200.20083713531 -228.6872882843 -56.976619720458
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/8/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 36
# Image dims: 1.44097220897674 1.44097220897674 6.0
# Image orig: -200.20083713531 -228.6872882843 -50.976619720458
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/8/T2SPIR//DICOM_anon/*dcm
# Image size: 288 288 32
# Image dims: 1.40625 1.40625 8.0
# Image orig: -197.23244190216 -223.68729019165 -37.628990173339
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/10/T1DUAL//DICOM_anon/*dcm
# Image size: 256 256 50
# Image dims: 1.89453125 1.89453125 5.5
# Image orig: -243.11873376369 -237.73130226135 -155.69004821777
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/10/T1DUAL//DICOM_anon/*dcm
# Image size: 256 256 50
# Image dims: 1.89453125 1.89453125 5.5
# Image orig: -243.11873376369 -237.73130226135 -150.19004821777
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/10/T2SPIR//DICOM_anon/*dcm
# Image size: 256 256 36
# Image dims: 1.69921875 1.69921875 7.7
# Image orig: -215.37475275993 -222.98672580718 -147.72044372558
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/13/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 30
# Image dims: 1.44097220897674 1.44097220897674 9.0
# Image orig: -196.36827278137 -219.67068481445 -108.50717163085
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/13/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 30
# Image dims: 1.44097220897674 1.44097220897674 9.0
# Image orig: -196.36827278137 -219.67068481445 -99.507171630859
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/13/T2SPIR//DICOM_anon/*dcm
# Image size: 320 320 30
# Image dims: 1.359375 1.359375 9.0
# Image orig: -206.36827468872 -229.6706867218 -90.507171630859
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/15/T1DUAL//DICOM_anon/*dcm
# Image size: 256 256 26
# Image dims: 1.69921875 1.69921875 9.0
# Image orig: -240.67453575134 -221.65929222106 -86.274360656738
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/15/T1DUAL//DICOM_anon/*dcm
# Image size: 256 256 26
# Image dims: 1.69921875 1.69921875 9.0
# Image orig: -240.67453575134 -221.65929222106 -77.274360656738
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/15/T2SPIR//DICOM_anon/*dcm
# Image size: 256 256 26
# Image dims: 1.58203125 1.58203125 9.0
# Image orig: -232.28246498107 -206.65929222106 -64.309600830078
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/19/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 30
# Image dims: 1.44097220897674 1.44097220897674 9.0
# Image orig: -202.23243951797 -211.3795967102 -93.848846435546
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/19/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 30
# Image dims: 1.44097220897674 1.44097220897674 9.0
# Image orig: -202.23243951797 -211.3795967102 -84.848846435546
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/19/T2SPIR//DICOM_anon/*dcm
# Image size: 320 320 30
# Image dims: 1.359375 1.359375 9.0
# Image orig: -212.23244142532 -221.37959861755 -75.848846435546
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/20/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 26
# Image dims: 1.44097220897674 1.44097220897674 9.0
# Image orig: -207.49999809265 -219.77059459686 -101.79637145996
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/20/T1DUAL//DICOM_anon/*dcm
# Image size: 288 288 26
# Image dims: 1.44097220897674 1.44097220897674 9.0
# Image orig: -207.49999809265 -219.77059459686 -92.79637145996
# Moving Image info for /pghbio/dbmi/batmanlab/Data/CombinedHealthyAbdominalOrganSegmentation/MR_data_batch1/20/T2SPIR//DICOM_anon/*dcm
# Image size: 320 320 26
# Image dims: 1.359375 1.359375 9.0
# Image orig: -217.5 -229.77059650421 -83.79637145996
